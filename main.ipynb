# %%
import pandas as pd
from sqlalchemy import create_engine
# from config import username
# from config import password
# from config import host_number
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-43181d14ac44> in <module>
#       1 import pandas as pd
#       2 from sqlalchemy import create_engine
# ----> 3 from config import username
#       4 from config import password
#       5 from config import host_number
#
# ModuleNotFoundError: No module named 'config'

# %%
# https://www.fhfa.gov/DataTools/Downloads/Pages/House-Price-Index.aspx
csv_file = "data/hpi_data.csv"
hpi_data_df = pd.read_csv(csv_file)
hpi_data_df.head()
# Out:
#       hpi_type     hpi_flavor frequency                   level  \
# 0  traditional  purchase-only   monthly  USA or Census Division
# 1  traditional  purchase-only   monthly  USA or Census Division
# 2  traditional  purchase-only   monthly  USA or Census Division
# 3  traditional  purchase-only   monthly  USA or Census Division
# 4  traditional  purchase-only   monthly  USA or Census Division
#
#                     place_name place_id    yr  period  index_nsa  index_sa
# 0  East North Central Division   DV_ENC  1991       1     100.00    100.00
# 1  East North Central Division   DV_ENC  1991       2     100.98    101.06
# 2  East North Central Division   DV_ENC  1991       3     101.33    100.95
# 3  East North Central Division   DV_ENC  1991       4     101.72    101.02
# 4  East North Central Division   DV_ENC  1991       5     102.35    101.40

# %%
#drop columns
hpi_data_clean = hpi_data_df[["hpi_type","hpi_flavor","frequency","level","place_name","place_id","yr","period","index_nsa"]]
hpi_data_clean.head()
# Out:
#       hpi_type     hpi_flavor frequency                   level  \
# 0  traditional  purchase-only   monthly  USA or Census Division
# 1  traditional  purchase-only   monthly  USA or Census Division
# 2  traditional  purchase-only   monthly  USA or Census Division
# 3  traditional  purchase-only   monthly  USA or Census Division
# 4  traditional  purchase-only   monthly  USA or Census Division
#
#                     place_name place_id    yr  period  index_nsa
# 0  East North Central Division   DV_ENC  1991       1     100.00
# 1  East North Central Division   DV_ENC  1991       2     100.98
# 2  East North Central Division   DV_ENC  1991       3     101.33
# 3  East North Central Division   DV_ENC  1991       4     101.72
# 4  East North Central Division   DV_ENC  1991       5     102.35

# %%
#state dataframe (quarterly)
state_df = hpi_data_df.loc[hpi_data_df["level"] == "State"]
state_df.head()
# Out:
#           hpi_type        hpi_flavor  frequency  level place_name place_id  \
# 64331  traditional  all-transactions  quarterly  State     Alaska       AK
# 64332  traditional  all-transactions  quarterly  State     Alaska       AK
# 64333  traditional  all-transactions  quarterly  State     Alaska       AK
# 64334  traditional  all-transactions  quarterly  State     Alaska       AK
# 64335  traditional  all-transactions  quarterly  State     Alaska       AK
#
#          yr  period  index_nsa  index_sa
# 64331  1975       1      62.74       NaN
# 64332  1975       2      64.16       NaN
# 64333  1975       3      62.24       NaN
# 64334  1975       4      68.51       NaN
# 64335  1976       1      71.31       NaN

# %%
#usa dataframe (monthly)
usa_df = hpi_data_df.loc[hpi_data_df["level"] == "USA or Census Division"]
usa_df.head()
# Out:
#       hpi_type     hpi_flavor frequency                   level  \
# 0  traditional  purchase-only   monthly  USA or Census Division
# 1  traditional  purchase-only   monthly  USA or Census Division
# 2  traditional  purchase-only   monthly  USA or Census Division
# 3  traditional  purchase-only   monthly  USA or Census Division
# 4  traditional  purchase-only   monthly  USA or Census Division
#
#                     place_name place_id    yr  period  index_nsa  index_sa
# 0  East North Central Division   DV_ENC  1991       1     100.00    100.00
# 1  East North Central Division   DV_ENC  1991       2     100.98    101.06
# 2  East North Central Division   DV_ENC  1991       3     101.33    100.95
# 3  East North Central Division   DV_ENC  1991       4     101.72    101.02
# 4  East North Central Division   DV_ENC  1991       5     102.35    101.40

# %%
#puerto rico dataframe (quarterly)
pr_df = hpi_data_df.loc[hpi_data_df["level"] == "Puerto Rico"]
pr_df.head()
# Out:
#              hpi_type        hpi_flavor  frequency        level   place_name  \
# 114523  developmental  all-transactions  quarterly  Puerto Rico  Puerto Rico
# 114524  developmental  all-transactions  quarterly  Puerto Rico  Puerto Rico
# 114525  developmental  all-transactions  quarterly  Puerto Rico  Puerto Rico
# 114526  developmental  all-transactions  quarterly  Puerto Rico  Puerto Rico
# 114527  developmental  all-transactions  quarterly  Puerto Rico  Puerto Rico
#
#        place_id    yr  period  index_nsa  index_sa
# 114523       PR  1995       1     100.00       NaN
# 114524       PR  1995       2     102.34       NaN
# 114525       PR  1995       3     106.22       NaN
# 114526       PR  1995       4     111.45       NaN
# 114527       PR  1996       1     113.46       NaN
